# %%
# %pip install openai

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key="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"
)

MODEL="llama-3.1-8b-instant"

# %%
prompt = "Write a one-sentence story about valorant."


response = client.chat.completions.create(
    model=MODEL,
    messages=[{"role": "user", "content": prompt}],
    temperature=0.7
)


print(f"Prompt: {prompt}")
print(f"Response: {response.choices[0].message.content}")
# Out:
# Prompt: Write a one-sentence story about valorant.
# Response: As a rookie Valorant player, Axel's clutch ultimate play in the final round of the qualifying match earned him and his team a spot in the championship tournament, catapulting him from unknown to Valorant legend overnight.
